# %%
input1 = float(input("enter 1st no. :"))
input2 = float(input("enter 2nd no. :"))
sum = input1 + input2
product = input1 * input2
division = input1/input2
subtraction = input1 - input2



print("sum , product , division , subtraction :" , sum , product , division , subtraction)
# Out:
# sum , product , division , subtraction : 119.0 3450.0 1.38 19.0
